# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# **Used to deal with numerical values**
# * distplot
# * pairplot
# * joinplot

# %%
df = pd.read_csv('Automobile_data.csv')
del df['symboling']
del df['wheel-base']
df.head()
# Out:
#   normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                 ?  alfa-romero       gas        std          two
# 1                 ?  alfa-romero       gas        std          two
# 2                 ?  alfa-romero       gas        std          two
# 3               164         audi       gas        std         four
# 4               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  length  width  ...  engine-size  \
# 0  convertible          rwd           front   168.8   64.1  ...          130
# 1  convertible          rwd           front   168.8   64.1  ...          130
# 2    hatchback          rwd           front   171.2   65.5  ...          152
# 3        sedan          fwd           front   176.6   66.2  ...          109
# 4        sedan          4wd           front   176.6   66.4  ...          136
#
#    fuel-system  bore stroke  compression-ratio horsepower peak-rpm city-mpg  \
# ...

# %% [markdown]
# ## Correlation with Heatmap

# %%
df.corr()
# Out:
#                      length     width    height  curb-weight  engine-size  \
# length             1.000000  0.841118  0.491029     0.877728     0.683360
# width              0.841118  1.000000  0.279210     0.867032     0.735433
# height             0.491029  0.279210  1.000000     0.295572     0.067149
# curb-weight        0.877728  0.867032  0.295572     1.000000     0.850594
# engine-size        0.683360  0.735433  0.067149     0.850594     1.000000
# compression-ratio  0.158414  0.181129  0.261214     0.151362     0.028971
# city-mpg          -0.670909 -0.642704 -0.048640    -0.757414    -0.653658
# highway-mpg       -0.704662 -0.677218 -0.107358    -0.797465    -0.677470
#
#                    compression-ratio  city-mpg  highway-mpg
# length                      0.158414 -0.670909    -0.704662
# width                       0.181129 -0.642704    -0.677218
# height                      0.261214 -0.048640    -0.107358
# curb-weight                 0.151362 -0.757414    -0.797465
# ...

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## Joinplot

# %%
# It is used for bivariate analysis
sns.jointplot(x='height', y='width', data=df, kind='hex')

# %%
sns.jointplot(x='height', y='width', data=df, kind='reg')

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='drive-wheels')
# Out:
# C:\Users\Prem Ranjan\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Dist plot

# %%
sns.distplot(df['length'])

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# **deal with categorical values**
# * boxplot
# * violinplot
# * countplot
# * barplot

# %% [markdown]
# ## Count plot

# %%
sns.countplot('body-style', data=df)

# %%
sns.countplot(y='body-style', data=df)

# %%
sns.countplot('drive-wheels', data=df, hue ='body-style')

# %% [markdown]
# ## Bar plot

# %% [markdown]
# ### It will show categorical features comparing with numerical features(Any), unlike Countplot shows frequency of one feature.

# %%
sns.barplot(x='body-style', y='height', data=df)

# %% [markdown]
# ## Box plot
# Here, starting shows 0 percentile and then increases by 25 percentile by a line.Also the dots in the figure shows outlier.
# Comparison can be with categorical data or numerical data.

# %%
sns.boxplot('body-style', 'height', data=df)

# %%
sns.boxplot('fuel-type','engine-size', data=df, hue='body-style', palette='rainbow')

# %%
sns.boxplot(data=df)

# %% [markdown]
# ## Violin plot
# It shows density in form of box plot

# %%
sns.violinplot('drive-wheels', 'height',data=df, hue='fuel-type')
